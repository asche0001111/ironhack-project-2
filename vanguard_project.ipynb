# %%
import pandas as pd

# %%
client_profiles = pd.read_csv("https://raw.githubusercontent.com/asche0001111/ironhack-project-2/main/df_final_demo.txt")

# %%
client_profiles
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
digital_footprint1 = pd.read_csv("https://raw.githubusercontent.com/asche0001111/ironhack-project-2/main/df_final_web_data_pt_1.txt")

# %%
digital_footprint1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
digital_footprint2 = pd.read_csv("https://raw.githubusercontent.com/asche0001111/ironhack-project-2/main/df_final_web_data_pt_2.txt")

# %%
digital_footprint2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# ...

# %%
experiment_roster = pd.read_csv("https://raw.githubusercontent.com/asche0001111/ironhack-project-2/main/df_final_experiment_clients.txt")

# %%
experiment_roster
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
digital_footprint1.visit_id.nunique()
# Out:
# 75256

# %%
digital_footprint1.groupby('client_id')['visitor_id'].nunique().value_counts()
# Out:
# visitor_id
# 1     54079
# 2      3742
# 3       423
# 4        92
# 5        22
# 6        17
# 7        13
# 8         2
# 12        1
# Name: count, dtype: int64

# %%
digital_footprint1.groupby('visitor_id')['client_id'].nunique().value_counts()
# Out:
# client_id
# 1    62346
# 2      586
# 3        3
# 4        1
# Name: count, dtype: int64

# %%
client_profiles.groupby('client_id')['num_accts'].value_counts()
# Out:
# client_id  num_accts
# 169        2.0          1
# 555        2.0          1
# 647        2.0          1
# 722        2.0          1
# 934        2.0          1
#                        ..
# 9999400    2.0          1
# 9999626    2.0          1
# 9999729    3.0          1
# 9999832    2.0          1
# 9999839    2.0          1
# Name: count, Length: 70595, dtype: int64

# %%
client_profiles["num_accts"].value_counts()
# Out:
# num_accts
# 2.0    55497
# 3.0    12529
# 4.0     2241
# 5.0      284
# 6.0       33
# 7.0        8
# 1.0        2
# 8.0        1
# Name: count, dtype: int64

# %%
digital_footprint1["process_step"].value_counts()
# Out:
# process_step
# start      108910
# step_1      73432
# step_2      61768
# step_3      53628
# confirm     45403
# Name: count, dtype: int64

# %%
pd.concat([digital_footprint1, digital_footprint2]).duplicated().sum()
# Out:
# 10764

# %%
df_join_w_dupes = pd.concat([digital_footprint1, digital_footprint2])

# %%
df_join_w_dupes[df_join_w_dupes.duplicated()]
# Out:
#         client_id             visitor_id                      visit_id  \
# 365       9358626  148475529_63668223960  223297395_36250329195_832161
# 368       5376894  622509328_44408201172  688984457_43441834354_912755
# 383        438567  923318467_50708963627  330543236_29863358529_771432
# 785       1423857  716830992_81930238382   568819166_80596727019_75889
# 1816       372523  730241475_25771921122   25331354_74479847014_854987
# ...           ...                    ...                           ...
# 412120    1672289  658797407_91003097342  430110748_90347503221_597628
# 412163    4408245   14058946_73585431797  994148957_84373994761_991865
# 412165    4408245   14058946_73585431797  994148957_84373994761_991865
# 412167    4408245   14058946_73585431797  994148957_84373994761_991865
# 412217    3897324   80177429_24869309091  149796456_64325617570_112561
#
#        process_step            date_time
# 365           start  2017-04-28 12:27:28
# ...

# %%
df_join = df_join_w_dupes.drop_duplicates()

# %%
df_join.shape
# Out:
# (744641, 5)

# %%
df_join.reset_index(inplace=True)

# %%
df_join
# Out:
#          index  client_id             visitor_id  \
# 0            0    9988021   580560515_7732621733
# 1            1    9988021   580560515_7732621733
# 2            2    9988021   580560515_7732621733
# 3            3    9988021   580560515_7732621733
# 4            4    9988021   580560515_7732621733
# ...        ...        ...                    ...
# 744636  412259    9668240   388766751_9038881013
# 744637  412260    9668240   388766751_9038881013
# 744638  412261    9668240   388766751_9038881013
# 744639  412262    9668240   388766751_9038881013
# 744640  412263     674799  947159805_81558194550
#
#                             visit_id process_step            date_time
# 0       781255054_21935453173_531117       step_3  2017-04-17 15:27:07
# 1       781255054_21935453173_531117       step_2  2017-04-17 15:26:51
# 2       781255054_21935453173_531117       step_3  2017-04-17 15:19:22
# 3       781255054_21935453173_531117       step_2  2017-04-17 15:19:13
# ...

# %%
df_join.drop("index", axis=1)
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 744636    9668240   388766751_9038881013   922267647_3096648104_968866
# 744637    9668240   388766751_9038881013   922267647_3096648104_968866
# 744638    9668240   388766751_9038881013   922267647_3096648104_968866
# 744639    9668240   388766751_9038881013   922267647_3096648104_968866
# 744640     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
df_x = pd.merge(df_join, experiment_roster, on="client_id", how="left")

# %%
df_x.drop("index", axis=1, inplace = True)

# %%
df_x.reset_index(inplace = True)

# %%
df_x["Variation"].value_counts()
# Out:
# Variation
# Test       176699
# Control    140536
# Name: count, dtype: int64

# %%
df_x["Variation"].isnull().sum()
# Out:
# 427406

# %%
df_x
# Out:
#          index  client_id             visitor_id  \
# 0            0    9988021   580560515_7732621733
# 1            1    9988021   580560515_7732621733
# 2            2    9988021   580560515_7732621733
# 3            3    9988021   580560515_7732621733
# 4            4    9988021   580560515_7732621733
# ...        ...        ...                    ...
# 744636  744636    9668240   388766751_9038881013
# 744637  744637    9668240   388766751_9038881013
# 744638  744638    9668240   388766751_9038881013
# 744639  744639    9668240   388766751_9038881013
# 744640  744640     674799  947159805_81558194550
#
#                             visit_id process_step            date_time  \
# 0       781255054_21935453173_531117       step_3  2017-04-17 15:27:07
# 1       781255054_21935453173_531117       step_2  2017-04-17 15:26:51
# 2       781255054_21935453173_531117       step_3  2017-04-17 15:19:22
# 3       781255054_21935453173_531117       step_2  2017-04-17 15:19:13
# ...

# %%
df_null = df_x[(df_x["Variation"] != "Test") & (df_x["Variation"] != "Control")]

# %%
df_null
# Out:
#          index  client_id             visitor_id  \
# 245        245    8932927  485163175_18149554449
# 270        270    1208567  490822748_12476046982
# 356        356    9838496  408959474_91766774102
# 859        859    2353261  387293592_26815377704
# 860        860    2353261  387293592_26815377704
# ...        ...        ...                    ...
# 744636  744636    9668240   388766751_9038881013
# 744637  744637    9668240   388766751_9038881013
# 744638  744638    9668240   388766751_9038881013
# 744639  744639    9668240   388766751_9038881013
# 744640  744640     674799  947159805_81558194550
#
#                             visit_id process_step            date_time  \
# 245     883578716_57691052399_945047       step_1  2017-04-13 22:37:49
# 270       63636232_1058424732_545130        start  2017-04-24 14:03:26
# 356     687233905_42314307889_453394        start  2017-03-24 21:26:14
# 859     269923351_29360137819_823850       step_1  2017-03-20 16:07:22
# ...

# %%
df_x.dropna(subset="Variation", inplace=True)

# %%
df_x.drop("index", axis=1, inplace=True)

# %%
df_x
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 629303    1574008  117364417_77840596075  528720790_71583064618_169151
# 629346    2908510  814969699_90652851448   562606085_36368381773_92090
# 629347    2908510  814969699_90652851448   562606085_36368381773_92090
# 629348    2908510  814969699_90652851448   562606085_36368381773_92090
# 629349    2908510  814969699_90652851448   562606085_36368381773_92090
#
#        process_step            date_time Variation
# 0            step_3  2017-04-17 15:27:07      Test
# ...

# %%
df_x
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 629303    1574008  117364417_77840596075  528720790_71583064618_169151
# 629346    2908510  814969699_90652851448   562606085_36368381773_92090
# 629347    2908510  814969699_90652851448   562606085_36368381773_92090
# 629348    2908510  814969699_90652851448   562606085_36368381773_92090
# 629349    2908510  814969699_90652851448   562606085_36368381773_92090
#
#        process_step            date_time Variation
# 0            step_3  2017-04-17 15:27:07      Test
# ...

# %%
df_x.groupby("Variation")["process_step"].value_counts()
# Out:
# Variation  process_step
# Control    start           45380
#            step_1          29544
#            step_2          25773
#            step_3          22503
#            confirm         17336
# Test       start           55773
#            step_1          38666
#            step_2          30899
#            step_3          25761
#            confirm         25600
# Name: count, dtype: int64

# %%
df_x["Variation"].value_counts()
# Out:
# Variation
# Test       176699
# Control    140536
# Name: count, dtype: int64

# %%
# Group by client_id, visitor_id, and visit_id and aggregate process_step into a list
grouped_steps = df_x.groupby(['client_id', 'visitor_id', 'visit_id'])['process_step'].apply(list).reset_index()

# Merge the grouped steps with the original DataFrame to retain other columns
merged_df = pd.merge(df_x, grouped_steps, on=['client_id', 'visitor_id', 'visit_id'], how='left')

# Rename the new column containing lists of process steps
merged_df.rename(columns={'process_step': 'process_step_list'}, inplace=True)

# Print or manipulate the merged DataFrame as needed
print(merged_df)
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 317230    1574008  117364417_77840596075  528720790_71583064618_169151
# 317231    2908510  814969699_90652851448   562606085_36368381773_92090
# 317232    2908510  814969699_90652851448   562606085_36368381773_92090
# 317233    2908510  814969699_90652851448   562606085_36368381773_92090
# 317234    2908510  814969699_90652851448   562606085_36368381773_92090
#
#        process_step_x            date_time Variation  \
# 0              step_3  2017-04-17 15:27:07      Test
# ...

# %%
merged_df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 317230    1574008  117364417_77840596075  528720790_71583064618_169151
# 317231    2908510  814969699_90652851448   562606085_36368381773_92090
# 317232    2908510  814969699_90652851448   562606085_36368381773_92090
# 317233    2908510  814969699_90652851448   562606085_36368381773_92090
# 317234    2908510  814969699_90652851448   562606085_36368381773_92090
#
#        process_step_x            date_time Variation  \
# 0              step_3  2017-04-17 15:27:07      Test
# ...

# %%
merged_df.dtypes
# Out:
# client_id          int64
# visitor_id        object
# visit_id          object
# process_step_x    object
# date_time         object
# Variation         object
# process_step_y    object
# dtype: object

# %%
# Assuming merged_df is your DataFrame with the process_step_list column

# Convert date_time column to datetime format
merged_df['date_time'] = pd.to_datetime(merged_df['date_time'])

# Calculate total_process_time
total_process_time = merged_df.groupby(['client_id', 'visitor_id', 'visit_id'])['date_time'].apply(lambda x: x.max() - x.min()).reset_index()

# Rename the column to total_process_time
total_process_time.rename(columns={'date_time': 'total_process_time'}, inplace=True)

# Merge total_process_time with the original DataFrame
final_df = pd.merge(merged_df, total_process_time, on=['client_id', 'visitor_id', 'visit_id'], how='left')

# Print or manipulate the final_df DataFrame as needed
final_df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 317230    1574008  117364417_77840596075  528720790_71583064618_169151
# 317231    2908510  814969699_90652851448   562606085_36368381773_92090
# 317232    2908510  814969699_90652851448   562606085_36368381773_92090
# 317233    2908510  814969699_90652851448   562606085_36368381773_92090
# 317234    2908510  814969699_90652851448   562606085_36368381773_92090
#
#        process_step_x           date_time Variation  \
# 0              step_3 2017-04-17 15:27:07      Test
# ...

# %%
final_df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 317230    1574008  117364417_77840596075  528720790_71583064618_169151
# 317231    2908510  814969699_90652851448   562606085_36368381773_92090
# 317232    2908510  814969699_90652851448   562606085_36368381773_92090
# 317233    2908510  814969699_90652851448   562606085_36368381773_92090
# 317234    2908510  814969699_90652851448   562606085_36368381773_92090
#
#        process_step_x           date_time Variation  \
# 0              step_3 2017-04-17 15:27:07      Test
# ...

# %%
dfx_final = final_df.drop_duplicates(subset=["client_id", "visitor_id", "visit_id"]).reset_index(drop=True)

# %%
dfx_final.rename(columns={"process_step_x": "final_step"}, inplace = True)

# %%
dfx_final.rename(columns={"process_step_y": "step_list"}, inplace = True)

# %%
dfx_final["total_process_time"] = pd.to_timedelta(dfx_final["total_process_time"]).astype(str)

# %%
dfx_final["total_process_time"] = dfx_final["total_process_time"].str.replace("0 days ", "")

# %%
dfx_final
# Out:
#        client_id             visitor_id                      visit_id  \
# 0        9988021   580560515_7732621733  781255054_21935453173_531117
# 1        8320017   39393514_33118319366  960651974_70596002104_312201
# 2        4033851  762728880_76361333336  949661017_22392791362_127391
# 3        1982004  618934751_10082078917   132494692_73738638511_70823
# 4        9294070  489274391_63794562906  116640698_27328181095_188045
# ...          ...                    ...                           ...
# 69442    6426623    27047012_3402532492  685634090_42070675506_389171
# 69443     433098    5505424_50616523266  773565250_67577573147_389841
# 69444    7049106  710348688_12741653529   412278907_8949064401_171038
# 69445    1574008  117364417_77840596075  528720790_71583064618_169151
# 69446    2908510  814969699_90652851448   562606085_36368381773_92090
#
#       final_step           date_time Variation  \
# 0         step_3 2017-04-17 15:27:07      Test
# ...

# %%
dfx_final.dtypes
# Out:
# client_id                      int64
# visitor_id                    object
# visit_id                      object
# final_step                    object
# date_time             datetime64[ns]
# Variation                     object
# step_list                     object
# total_process_time            object
# dtype: object

# %%
dfx_final["total_process_time"] = pd.to_datetime(dfx_final["total_process_time"], format="%H:%M:%S").dt.time

# %%
dfx_final["IsFinal"] = dfx_final["final_step"].apply(lambda x: True if x == "confirm" else False)

# %%
dfx_final.duplicated(subset=["client_id","visit_id","visitor_id"]).sum()
# Out:
# 0

# %%
dfx_final
# Out:
#        client_id             visitor_id                      visit_id  \
# 0        9988021   580560515_7732621733  781255054_21935453173_531117
# 1        8320017   39393514_33118319366  960651974_70596002104_312201
# 2        4033851  762728880_76361333336  949661017_22392791362_127391
# 3        1982004  618934751_10082078917   132494692_73738638511_70823
# 4        9294070  489274391_63794562906  116640698_27328181095_188045
# ...          ...                    ...                           ...
# 69442    6426623    27047012_3402532492  685634090_42070675506_389171
# 69443     433098    5505424_50616523266  773565250_67577573147_389841
# 69444    7049106  710348688_12741653529   412278907_8949064401_171038
# 69445    1574008  117364417_77840596075  528720790_71583064618_169151
# 69446    2908510  814969699_90652851448   562606085_36368381773_92090
#
#       final_step           date_time Variation  \
# 0         step_3 2017-04-17 15:27:07      Test
# ...

# %%
dfx_final.groupby("Variation")["IsFinal"].value_counts()
# Out:
# Variation  IsFinal
# Control    False      17305
#            True       14938
# Test       True       20976
#            False      16228
# Name: count, dtype: int64

# %%
dfx_final.groupby("Variation")["final_step"].value_counts()
# Out:
# Variation  final_step
# Control    confirm       14938
#            start          9716
#            step_1         3565
#            step_3         2407
#            step_2         1617
# Test       confirm       20976
#            start          9487
#            step_1         3262
#            step_3         1967
#            step_2         1512
# Name: count, dtype: int64

# %%
dfx_final["date_time"].max()
# Out:
# Timestamp('2017-06-20 23:57:06')

# %%
client_profiles
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
client_profiles["num_accts"].corr(dfx_final["IsFinal"], method="spearman")
# Out:
# 0.0035506370784583077

# %%
#mateo says to put a comment here
#numver of accoiubnts doesnt influence signups

# %%
dfx_final["step_list"].apply(len).corr(dfx_final["IsFinal"], method="spearman")
# Out:
# 0.41125158765695397

# %%
#Get a table with all the unique instances of client_id, so that we could run demographic analysis without running into issues

# %%
full_client_profiles_int = dfx_final.groupby("client_id").first().reset_index()

# %%
full_client_profiles_int
# Out:
#        client_id             visitor_id                      visit_id  \
# 0            555  402506806_56087378777  637149525_38041617439_716659
# 1            647   66758770_53988066587   40369564_40101682850_311847
# 2            934  810392784_45004760546    7076463_57954418406_971348
# 3           1028   42237450_62128060588  557292053_87239438319_391157
# 4           1104  194240915_18158000533  543158812_46395476577_767725
# ...          ...                    ...                           ...
# 50495    9999150  665127594_52605538620  982803842_91891255980_123078
# 50496    9999400  915967319_19082377501  288904166_90826265353_276104
# 50497    9999626   52633065_71189986073  182723364_27031318473_880901
# 50498    9999729  604429154_69247391147   99583652_41711450505_426179
# 50499    9999832  145538019_54444341400  472154369_16714624241_585315
#
#       final_step           date_time Variation  \
# 0        confirm 2017-04-15 13:00:34      Test
# ...

# %%
full_client_profiles = pd.merge(full_client_profiles_int, client_profiles, on="client_id", how="inner")

# %%
full_client_profiles
# Out:
#        client_id             visitor_id                      visit_id  \
# 0            555  402506806_56087378777  637149525_38041617439_716659
# 1            647   66758770_53988066587   40369564_40101682850_311847
# 2            934  810392784_45004760546    7076463_57954418406_971348
# 3           1028   42237450_62128060588  557292053_87239438319_391157
# 4           1104  194240915_18158000533  543158812_46395476577_767725
# ...          ...                    ...                           ...
# 50495    9999150  665127594_52605538620  982803842_91891255980_123078
# 50496    9999400  915967319_19082377501  288904166_90826265353_276104
# 50497    9999626   52633065_71189986073  182723364_27031318473_880901
# 50498    9999729  604429154_69247391147   99583652_41711450505_426179
# 50499    9999832  145538019_54444341400  472154369_16714624241_585315
#
#       final_step           date_time Variation  \
# 0        confirm 2017-04-15 13:00:34      Test
# ...

# %%
#Done dataset discovery: Understood the nature and structure of your datasets using Python with libraries such as Pandas, Matplotlib, and Seaborn.
import seaborn as sns

# %%
sns.countplot(data=dfx_final, x="final_step")
# Out:
# <Axes: xlabel='final_step', ylabel='count'>

# %%
dfx_final["total_process_time_seconds"] = dfx_final["total_process_time"].apply(lambda x: x.hour * 3600 + x.minute * 60 + x.second)

Q1 = dfx_final["total_process_time_seconds"].quantile(0.25)
Q3 = dfx_final["total_process_time_seconds"].quantile(0.75)
IQR = Q3 - Q1

# Define the range for normal data points
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out outliers
filtered_data = dfx_final[(dfx_final["total_process_time_seconds"] >= lower_bound) & 
                          (dfx_final["total_process_time_seconds"] <= upper_bound)]

# Group the filtered data
grouped_data = filtered_data.groupby("total_process_time_seconds").size().reset_index(name='count')

# Create the bar plot
sns.barplot(data=grouped_data, x="total_process_time_seconds", y='count')
# Out:
# <Axes: xlabel='total_process_time_seconds', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt  # Correct import statement

# Filter data for process times up to 10 minutes (600 seconds)
filtered_data_up_to_10_min = filtered_data[filtered_data["total_process_time_seconds"] <= 600]

# Group the filtered data
grouped_data = filtered_data_up_to_10_min.groupby("total_process_time_seconds").size().reset_index(name='count')

# Create the bar plot
sns.barplot(data=grouped_data, x="total_process_time_seconds", y='count')

# Set y-axis limit to 1000 using plt.ylim() function from matplotlib.pyplot
plt.ylim(0, 1000)

# Show the plot
plt.show()

# %%
dfx_final
# Out:
#        client_id             visitor_id                      visit_id  \
# 0        9988021   580560515_7732621733  781255054_21935453173_531117
# 1        8320017   39393514_33118319366  960651974_70596002104_312201
# 2        4033851  762728880_76361333336  949661017_22392791362_127391
# 3        1982004  618934751_10082078917   132494692_73738638511_70823
# 4        9294070  489274391_63794562906  116640698_27328181095_188045
# ...          ...                    ...                           ...
# 69442    6426623    27047012_3402532492  685634090_42070675506_389171
# 69443     433098    5505424_50616523266  773565250_67577573147_389841
# 69444    7049106  710348688_12741653529   412278907_8949064401_171038
# 69445    1574008  117364417_77840596075  528720790_71583064618_169151
# 69446    2908510  814969699_90652851448   562606085_36368381773_92090
#
#       final_step           date_time Variation  \
# 0         step_3 2017-04-17 15:27:07      Test
# ...

# %%
import numpy as np
from scipy.stats import chi2_contingency

# %%
#H0 = there is no significant difference in completion rates between the old and new designs
#H1 = there is a significant difference in completion rates between the old and new designs
observed = np.array([[32243*0.463, 32243*(1-0.463)], [20976*0.563, 20976*(1-0.563)]])

chi2, p, dof, expected = chi2_contingency(observed)
print(chi2, p, dof, expected)
# Out:
# 507.94854624656284 1.772368442050218e-112 1 [[16199.35055659 16043.64944341]
#  [10538.64644341 10437.35355659]]

# %%
dfx_final.groupby("Variation")["final_step"].value_counts()
# Out:
# Variation  final_step
# Control    confirm       14938
#            start          9716
#            step_1         3565
#            step_3         2407
#            step_2         1617
# Test       confirm       20976
#            start          9487
#            step_1         3262
#            step_3         1967
#            step_2         1512
# Name: count, dtype: int64

# %%
dfx_final.groupby("Variation")["IsFinal"].value_counts()
# Out:
# Variation  IsFinal
# Control    False      17305
#            True       14938
# Test       True       20976
#            False      16228
# Name: count, dtype: int64

# %%
observed_data = dfx_final.groupby("Variation")["IsFinal"].value_counts().unstack()
chi2, p, dof, expected = chi2_contingency(observed_data)

# %%
print(chi2, p, dof, expected)
# Out:
# 698.4936623915828 6.357226236803568e-154 1 [[15568.77214279 16674.22785721]
#  [17964.22785721 19239.77214279]]

# %%
#Done dataset discovery: Understood the nature and structure of your datasets using Python with libraries such as Pandas, Matplotlib, and Seaborn.

# %%
#done, mostly, add some graphs and charts

# %%
full_client_profiles[full_client_profiles["Variation"] == "Test"]["bal"].mean()
# Out:
# 148962.60503171248

# %%
full_client_profiles[full_client_profiles["Variation"] == "Control"]["bal"].mean()
# Out:
# 150147.3266595826

# %%
full_client_profiles
# Out:
#        client_id             visitor_id                      visit_id  \
# 0            555  402506806_56087378777  637149525_38041617439_716659
# 1            647   66758770_53988066587   40369564_40101682850_311847
# 2            934  810392784_45004760546    7076463_57954418406_971348
# 3           1028   42237450_62128060588  557292053_87239438319_391157
# 4           1104  194240915_18158000533  543158812_46395476577_767725
# ...          ...                    ...                           ...
# 50495    9999150  665127594_52605538620  982803842_91891255980_123078
# 50496    9999400  915967319_19082377501  288904166_90826265353_276104
# 50497    9999626   52633065_71189986073  182723364_27031318473_880901
# 50498    9999729  604429154_69247391147   99583652_41711450505_426179
# 50499    9999832  145538019_54444341400  472154369_16714624241_585315
#
#       final_step           date_time Variation  \
# 0        confirm 2017-04-15 13:00:34      Test
# ...

# %%
#confirm if the difference in completion rate of the new design and the old design is statistically significant

# %%
completion_rate_ctrl = dfx_final[dfx_final["Variation"] == "Control"]["IsFinal"].sum() / len(dfx_final[dfx_final["Variation"] == "Control"])

# %%
completion_rate_ctrl
# Out:
# 0.46329435846540334

# %%
completion_rate_test = dfx_final[dfx_final["Variation"] == "Test"]["IsFinal"].sum() / len(dfx_final[dfx_final["Variation"] == "Test"])

# %%
completion_rate_test
# Out:
# 0.5638103429738738

# %%
#H0 : no statistical difference
#H1 : test statistically varies from control

# %%
alpha = 0.05
contingency = pd.crosstab(dfx_final["Variation"], dfx_final["IsFinal"])

# %%
contingency
# Out:
# IsFinal    False  True
# Variation
# Control    17305  14938
# Test       16228  20976

# %%
chi2, p_value, dof, expected = chi2_contingency(contingency)

# Interpret the results
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Degrees of freedom:", dof)
print("Expected frequencies:")
print(expected)
# Out:
# Chi-square statistic: 698.4936623915828
# P-value: 6.357226236803568e-154
# Degrees of freedom: 1
# Expected frequencies:
# [[15568.77214279 16674.22785721]
#  [17964.22785721 19239.77214279]]

# %%
if p_value < alpha:
    print("Null hypothesis rejected")
else:
    print("Null hypothesis failed to reject")
#proven to be statistically significant due to very low p value, hence the new version is statistically different
# Out:
# Null hypothesis rejected

# %%
#carry out an analysis to see if the observed increase in rate meets or exceeds the 5% threshold

# %%
percentage_change = completion_rate_test - completion_rate_ctrl

# %%
print(percentage_change)
# Out:
# 0.10051598450847044

# %%
#conduct a test to see if there is a difference between the finalized completion times of the old and new design

#H0 = there is no statistical difference between the average time of completion of the old and new website design
#H1 = The new design takes less time on average

ctrl_time = dfx_final[(dfx_final["Variation"] == "Control") & (dfx_final["IsFinal"] == True)]["total_process_time_seconds"].mean()
test_time = dfx_final[(dfx_final["Variation"] == "Test") & (dfx_final["IsFinal"] == True)]["total_process_time_seconds"].mean()
time_std = dfx_final[dfx_final["IsFinal"] == True]["total_process_time_seconds"].std()
time_n = dfx_final[dfx_final["IsFinal"] == True]["total_process_time_seconds"].count()

# %%
print(ctrl_time, test_time, time_std, time_n)
# Out:
# 366.5248359887535 339.97006102212055 479.1078479960433 35914

# %%
dfx_final[dfx_final["IsFinal"] == True]["total_process_time_seconds"].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    131.0
# 0.50    228.0
# 0.75    408.0
# Name: total_process_time_seconds, dtype: float64

# %%
import scipy.stats as st
stat1 = (test_time - ctrl_time)/(time_std/np.sqrt(time_n))
p_value = st.t.sf(abs(stat1), time_n-1)

# %%
print(stat1, p_value)
# Out:
# -10.503673892009255 4.5275735782713354e-26

# %%
#H0 is thrown out

# %%
#total customer retention rate
dfx_final[dfx_final["IsFinal"] == True]["final_step"].count() / dfx_final["final_step"].count()
# Out:
# 0.5171425691534551

# %%
#tenure year analysis
import matplotlib.pyplot as plt
completed_profiles = full_client_profiles[full_client_profiles["IsFinal"] == True]

completion_counts_per_tenure = completed_profiles.groupby("clnt_tenure_yr")["IsFinal"].count()

completion_counts_per_tenure.plot(kind="bar", figsize=(10, 6))
plt.title("Distribution of Completion Rates per Tenure Year")
plt.xlabel("Tenure Year")
plt.ylabel("Number of Completed Profiles")
plt.show()

# %%
total_profiles_per_tenure = full_client_profiles.groupby("clnt_tenure_yr")["client_id"].count()

# Group by tenure year and count the number of completed profiles for each tenure year
completion_counts_per_tenure = completed_profiles.groupby("clnt_tenure_yr")["client_id"].count()

# Calculate the completion rates per tenure year as proportions
completion_rates_per_tenure = completion_counts_per_tenure / total_profiles_per_tenure

# Plot the distribution
completion_rates_per_tenure.plot(kind="bar", figsize=(10, 6))
plt.title("Completion Rates per Tenure Year")
plt.xlabel("Tenure Year")
plt.ylabel("Completion Rate")
plt.show()

# %%
df_x["Variation"].value_counts()
# Out:
# Variation
# Test       176699
# Control    140536
# Name: count, dtype: int64

# %%
tenure_yr = full_client_profiles["clnt_tenure_yr"]
completion_rate = full_client_profiles["IsFinal"]

# %%
tenure_yr
# Out:
# 0         3.0
# 1        12.0
# 2         9.0
# 3        12.0
# 4         5.0
#          ...
# 50495     5.0
# 50496     7.0
# 50497     9.0
# 50498    10.0
# 50499    23.0
# Name: clnt_tenure_yr, Length: 50500, dtype: float64

# %%
completion_rate
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 50495    False
# 50496     True
# 50497    False
# 50498    False
# 50499    False
# Name: IsFinal, Length: 50500, dtype: bool

# %%
from scipy import stats
correlation_coefficient, p_value = stats.pointbiserialr(tenure_yr, completion_rate)

print("Point-Biserial Correlation Coefficient:", correlation_coefficient)
print("p-value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 2
#       1 from scipy import stats
# ----> 2 correlation_coefficient, p_value = stats.pointbiserialr(tenure_yr, completion_rate)
#       4 print("Point-Biserial Correlation Coefficient:", correlation_coefficient)
#       5 print("p-value:", p_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/stats/_stats_py.py:5587, in pointbiserialr(x, y)
#    5499 def pointbiserialr(x, y):
#    5500     r"""Calculate a point biserial correlation coefficient and its p-value.
#    5501
#    5502     The point biserial correlation is used to measure the relationship
#    (...)
#    5585
#    5586     """
# -> 5587     rpb, prob = pearsonr(x, y)
#    5588     # create result object with alias for backward compatibility
#    5589     res = SignificanceResult(rpb, prob)
#
# ...

# %%
# Identify rows with invalid values
invalid_values = np.isnan(tenure_yr) | np.isnan(completion_rate) | np.isinf(tenure_yr) | np.isinf(completion_rate)

# Filter out rows with invalid values
tenure_yr_clean = tenure_yr[~invalid_values]
completion_rate_clean = completion_rate[~invalid_values]

# %%
correlation_coefficient, p_value = stats.pointbiserialr(tenure_yr_clean, completion_rate_clean)

print("Point-Biserial Correlation Coefficient:", correlation_coefficient)
print("p-value:", p_value)
# Out:
# Point-Biserial Correlation Coefficient: -0.02830426946968559
# p-value: 2.0050377902689402e-10

# %%
#same thing but w p value below

# %%
import pandas as pd
from scipy.stats import ttest_ind

# Assuming you have imported your DataFrame full_client_profiles

# Subset the DataFrame to include only the columns you need
subset = full_client_profiles[['IsFinal', 'clnt_tenure_yr']]

# Drop any rows with missing values
subset.dropna(inplace=True)

# Separate the two groups for comparison based on the values of 'IsFinal'
group1 = subset[subset['IsFinal'] == True]['clnt_tenure_yr']
group2 = subset[subset['IsFinal'] == False]['clnt_tenure_yr']

# Perform the t-test
t_stat, p_value = ttest_ind(group1, group2)

# Print the results
print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: -6.36226076171896
# P-value: 2.0050377902688678e-10
# /var/folders/7m/3h9k282d7dqfggyrf3bb01lc0000gp/T/ipykernel_56980/3109018499.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset.dropna(inplace=True)
